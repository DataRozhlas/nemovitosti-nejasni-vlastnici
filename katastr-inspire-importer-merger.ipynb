# %%
#python 2.x 32bit!

# %%
for file in os.listdir('./scratch/gml/'):
    if file.endswith('.xml'):
        #zkonvertovat
        order = 'C:/OSGeo4W64/bin/ogr2ogr.exe --config GDAL_DATA "C:/OSGeo4W64/share/gdal/" -where "OGR_GEOMETRY=\'Polygon\'" -f "esri shapefile" F:/DEVEL/DATA/znarodneni-katastr/scratch/shp/' + file.split('.')[0] + '.shp F:/DEVEL/DATA/znarodneni-katastr/scratch/gml/' + file + ' CadastralParcel'
        print(order)
# Out:
# C:/OSGeo4W64/bin/ogr2ogr.exe --config GDAL_DATA "C:/OSGeo4W64/share/gdal/" -where "OGR_GEOMETRY='Polygon'" -f "esri shapefile" F:/DEVEL/DATA/znarodneni-katastr/scratch/shp/600041.shp F:/DEVEL/DATA/znarodneni-katastr/scratch/gml/600041.xml CadastralParcel
# C:/OSGeo4W64/bin/ogr2ogr.exe --config GDAL_DATA "C:/OSGeo4W64/share/gdal/" -where "OGR_GEOMETRY='Polygon'" -f "esri shapefile" F:/DEVEL/DATA/znarodneni-katastr/scratch/shp/600067.shp F:/DEVEL/DATA/znarodneni-katastr/scratch/gml/600067.xml CadastralParcel
# C:/OSGeo4W64/bin/ogr2ogr.exe --config GDAL_DATA "C:/OSGeo4W64/share/gdal/" -where "OGR_GEOMETRY='Polygon'" -f "esri shapefile" F:/DEVEL/DATA/znarodneni-katastr/scratch/shp/600083.shp F:/DEVEL/DATA/znarodneni-katastr/scratch/gml/600083.xml CadastralParcel
# ...
